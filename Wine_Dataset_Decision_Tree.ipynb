# %% [markdown]
# <a href="https://colab.research.google.com/github/BallderJ/upsrj-machine-learning/blob/main/Wine_Dataset_Decision_Tree.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Importamos las librerías necesarias
from sklearn.datasets import load_wine
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier, plot_tree
import matplotlib.pyplot as plt
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report, confusion_matrix

# %%
#Cargamos la base de datos Wine
data = load_wine()
print(data.keys())
# Out:
# dict_keys(['data', 'target', 'frame', 'target_names', 'DESCR', 'feature_names'])

# %%
X = wine.data
y = wine.target
feature_names = wine.feature_names
target_names = wine.target_names

# %%
#Dividir los datos
X_train, X_test, y_train, y_test = train_test_split(
    X,
    y,
    test_size=0.30,
    random_state=42,
    stratify=y
)

# %%
#Generar el modelo de árbol
model = DecisionTreeClassifier(max_depth=3)
model.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(max_depth=3)

# %%
#Realizar predicciones y evaluamos
y_pred = model.predict(X_test)

# %%
#Evaluacion del modelo
print(f"accuracy score: {accuracy_score(y_test, y_pred)}")
print(f"confusion matrix: {confusion_matrix(y_test, y_pred)}")
print(f"classification report: {classification_report(y_test, y_pred)}")
# Out:
# accuracy score: 0.9814814814814815
# confusion matrix: [[17  1  0]
#  [ 0 21  0]
#  [ 0  0 15]]
# classification report:               precision    recall  f1-score   support
#
#            0       1.00      0.94      0.97        18
#            1       0.95      1.00      0.98        21
#            2       1.00      1.00      1.00        15
#
#     accuracy                           0.98        54
#    macro avg       0.98      0.98      0.98        54
# weighted avg       0.98      0.98      0.98        54

# %%
#Visualizar el árbol generado
plt.figure(figsize=(20,10))
plot_tree(model,
          feature_names=wine.feature_names,
          class_names=wine.target_names,
          filled=True,
          rounded=True)
plt.title("Árbol de Decisión Binaria - Wine Dataset")
plt.show()
